# %%
import numpy as np
a = np.arange(1,6)
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
b = a

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
# a2 = [7.47, 18.09, 13.34 , 17.15, 18.25]
# b2 = [6.6,20.7,17.2,19.4,21.8]

# %%
plt.plot(a,b)

# %%
plt.plot(a,b**2)

# %%
plt.plot(a,b**3)

# %%
plt.plot(a,b**4)

# %%
plt.plot(a,b**5)
