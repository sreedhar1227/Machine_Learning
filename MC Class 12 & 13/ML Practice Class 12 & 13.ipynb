# %% [markdown]
# # Time Series Analysis

# %%
-->The data which recorded with time is called Time Series.
-->Components of Time Series : 
    1)Seasonality : 
    2)Residuals :
    3)Stationary :
-->It will predict future values based on previously observed values.
-->Diff b/w time series and regression : 
    -->Time sreies data should be in order. in regression order is not important.
    .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_airline=pd.read_csv('airline_passengers.csv')
df_airline.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                    112.0
# 1  1949-02                    118.0
# 2  1949-03                    132.0
# 3  1949-04                    129.0
# 4  1949-05                    121.0

# %%
df_airline.isnull().sum()
# Out:
# Month                      0
# Thousands of Passengers    1
# dtype: int64

# %%
df_airline.tail()
# Out:
#                                                  Month  \
# 140                                            1960-09
# 141                                            1960-10
# 142                                            1960-11
# 143                                            1960-12
# 144  International airline passengers: monthly tota...
#
#      Thousands of Passengers
# 140                    508.0
# 141                    461.0
# 142                    390.0
# 143                    432.0
# 144                      NaN

# %%
df_airline.dropna(axis=0,inplace=True)
df_airline.isnull().sum()
# Out:
# Month                      0
# Thousands of Passengers    0
# dtype: int64

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    object
#  1   Thousands of Passengers  144 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.4+ KB

# %%
df_airline['Month']=pd.to_datetime(df_airline['Month'])

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    144 non-null    datetime64[ns]
#  1   Thousands of Passengers  144 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.4 KB

# %%
df_airline.head()
# Out:
#        Month  Thousands of Passengers
# 0 1949-01-01                    112.0
# 1 1949-02-01                    118.0
# 2 1949-03-01                    132.0
# 3 1949-04-01                    129.0
# 4 1949-05-01                    121.0

# %%
df_airline.set_index('Month',inplace=True)

# %%
df_airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                    112.0
# 1949-02-01                    118.0
# 1949-03-01                    132.0
# 1949-04-01                    129.0
# 1949-05-01                    121.0

# %%
df_airline.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
#Ho: It is non stationary (value of p)
#H1: It is stationary

def adf_test(series):
    result=adfuller(series)
    print('p- value: {}'.format(result[1]))
    
    if result[1] <=0.05:
        print("reject the null hypothesis")
    else:
        print("accept the null hypothesis")

# %%
adf_test(df_airline['Thousands of Passengers'])
# Out:
# p- value: 0.9918802434376411
# accept the null hypothesis

# %%
## Use Techniques Differencing

df_airline['Passengers First Difference']=df_airline['Thousands of Passengers']-df_airline['Thousands of Passengers'].shift(2)

# %%
df_airline.head()
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1949-01-01                    112.0                          NaN
# 1949-02-01                    118.0                          NaN
# 1949-03-01                    132.0                         20.0
# 1949-04-01                    129.0                         11.0
# 1949-05-01                    121.0                        -11.0

# %%
adf_test(df_airline['Passengers First Difference'].dropna())
# Out:
# p- value: 0.038629757676988535
# reject the null hypothesis

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf=plot_acf(df_airline["Passengers First Difference"].dropna())
pacf=plot_acf(df_airline["Passengers First Difference"].dropna())

# %%
### split train and test data

df_airline
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1949-01-01                    112.0                          NaN
# 1949-02-01                    118.0                          NaN
# 1949-03-01                    132.0                         20.0
# 1949-04-01                    129.0                         11.0
# 1949-05-01                    121.0                        -11.0
# ...                             ...                          ...
# 1960-08-01                    606.0                         71.0
# 1960-09-01                    508.0                       -114.0
# 1960-10-01                    461.0                       -145.0
# 1960-11-01                    390.0                       -118.0
# 1960-12-01                    432.0                        -29.0
#
# [144 rows x 2 columns]

# %%
from datetime import datetime, timedelta
train_dataset_end=datetime(1955,12,1)   # 1/1/1949 to 1/12/1955  (Training)
test_dataset_end=datetime(1960,12,1)    # 1/1/1956 to 1/12/1960  (Testing)

# %%
train_data=df_airline[:train_dataset_end]  #1/1/1949 to 1/12/1955

test_data=df_airline[train_dataset_end+timedelta(days=1):test_dataset_end]   # 1/1/1956 to 1/12/1960

# %%
##prediction

pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
pred_start_date
# Out:
# Timestamp('1956-01-01 00:00:00')

# %%
pred_end_date
# Out:
# Timestamp('1960-12-01 00:00:00')

# %%
test_data
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1956-01-01                    284.0                         47.0
# 1956-02-01                    277.0                         -1.0
# 1956-03-01                    317.0                         33.0
# 1956-04-01                    313.0                         36.0
# 1956-05-01                    318.0                          1.0
# 1956-06-01                    374.0                         61.0
# 1956-07-01                    413.0                         95.0
# 1956-08-01                    405.0                         31.0
# 1956-09-01                    355.0                        -58.0
# 1956-10-01                    306.0                        -99.0
# 1956-11-01                    271.0                        -84.0
# 1956-12-01                    306.0                          0.0
# 1957-01-01                    315.0                         44.0
# 1957-02-01                    301.0                         -5.0
# 1957-03-01                    356.0                         41.0
# 1957-04-01                    348.0                         47.0
# 1957-05-01                    355.0                         -1.0
# 1957-06-01                    422.0                         74.0
# 1957-07-01                    465.0                        110.0
# 1957-08-01                    467.0                         45.0
# 1957-09-01                    404.0                        -61.0
# 1957-10-01                    347.0                       -120.0
# 1957-11-01                    305.0                        -99.0
# 1957-12-01                    336.0                        -11.0
# 1958-01-01                    340.0                         35.0
# 1958-02-01                    318.0                        -18.0
# 1958-03-01                    362.0                         22.0
# 1958-04-01                    348.0                         30.0
# 1958-05-01                    363.0                          1.0
# 1958-06-01                    435.0                         87.0
# 1958-07-01                    491.0                        128.0
# 1958-08-01                    505.0                         70.0
# 1958-09-01                    404.0                        -87.0
# 1958-10-01                    359.0                       -146.0
# 1958-11-01                    310.0                        -94.0
# 1958-12-01                    337.0                        -22.0
# 1959-01-01                    360.0                         50.0
# 1959-02-01                    342.0                          5.0
# 1959-03-01                    406.0                         46.0
# 1959-04-01                    396.0                         54.0
# 1959-05-01                    420.0                         14.0
# 1959-06-01                    472.0                         76.0
# 1959-07-01                    548.0                        128.0
# 1959-08-01                    559.0                         87.0
# 1959-09-01                    463.0                        -85.0
# 1959-10-01                    407.0                       -152.0
# 1959-11-01                    362.0                       -101.0
# 1959-12-01                    405.0                         -2.0
# 1960-01-01                    417.0                         55.0
# 1960-02-01                    391.0                        -14.0
# 1960-03-01                    419.0                          2.0
# 1960-04-01                    461.0                         70.0
# 1960-05-01                    472.0                         53.0
# 1960-06-01                    535.0                         74.0
# 1960-07-01                    622.0                        150.0
# 1960-08-01                    606.0                         71.0
# 1960-09-01                    508.0                       -114.0
# 1960-10-01                    461.0                       -145.0
# 1960-11-01                    390.0                       -118.0
# 1960-12-01                    432.0                        -29.0

# %%
## create a ARIMA model

from statsmodels.tsa.arima.model import ARIMA

# %%
train_data
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1949-01-01                    112.0                          NaN
# 1949-02-01                    118.0                          NaN
# 1949-03-01                    132.0                         20.0
# 1949-04-01                    129.0                         11.0
# 1949-05-01                    121.0                        -11.0
# ...                             ...                          ...
# 1955-08-01                    347.0                         32.0
# 1955-09-01                    312.0                        -52.0
# 1955-10-01                    274.0                        -73.0
# 1955-11-01                    237.0                        -75.0
# 1955-12-01                    278.0                          4.0
#
# [84 rows x 2 columns]

# %%
#import warnings
#warnings.filterwarnings('ignore')

# %%
model_ARIMA=ARIMA(train_data['Thousands of Passengers'],order=(14,2,12))   # (p=14(PACF),d,q(ACF))

# %%
model_ARIMA_fit=model_ARIMA.fit()

# %%
test_data
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 
IMA_fit.resid.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
test_data['Predicted_ARIMA']=pred

# %%
test_data[['Thousands of Passengers','Predicted_ARIMA']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df_airline.head()
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1949-01-01                    112.0                          NaN
# 1949-02-01                    118.0                          NaN
# 1949-03-01                    132.0                         20.0
# 1949-04-01                    129.0                         11.0
# 1949-05-01                    121.0                        -11.0

# %%
df_airline.tail()
# Out:
#             Thousands of Passengers  Passengers First Difference
# Month
# 1960-08-01                    606.0                         71.0
# 1960-09-01                    508.0                       -114.0
# 1960-10-01                    461.0                       -145.0
# 1960-11-01                    390.0                       -118.0
# 1960-12-01                    432.0                        -29.0

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[df_airline.index[-1]+DateOffset(months=x)for x in range(0,25)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df_airline.columns)

# %%
future_datest_df.head()
# Out:
#            Thousands of Passengers Passengers First Difference
# 1961-01-01                     NaN                         NaN
# 1961-02-01                     NaN                         NaN
# 1961-03-01                     NaN                         NaN
# 1961-04-01                     NaN                         NaN
# 1961-05-01                     NaN                         NaN

# %%
future_datest_df.tail()
# Out:
#            Thousands of Passengers Passengers First Difference
# 1962-08-01                     NaN                         NaN
# 1962-09-01                     NaN                         NaN
# 1962-10-01                     NaN                         NaN
# 1962-11-01                     NaN                         NaN
# 1962-12-01                     NaN                         NaN

# %%
future_df=pd.concat([df_airline,future_datest_df])

# %%
future_df
# Out:
#             Thousands of Passengers  Passengers First Difference
# 1949-01-01                    112.0                          NaN
# 1949-02-01                    118.0                          NaN
# 1949-03-01                    132.0                         20.0
# 1949-04-01                    129.0                         11.0
# 1949-05-01                    121.0                        -11.0
# ...                             ...                          ...
# 1962-08-01                      NaN                          NaN
# 1962-09-01                      NaN                          NaN
# 1962-10-01                      NaN                          NaN
# 1962-11-01                      NaN                          NaN
# 1962-12-01                      NaN                          NaN
#
# [168 rows x 2 columns]

# %%
future_df['forecast']=model_ARIMA_fit.predict(start='1961-01-01',end='1962-12-01')
future_df[['Thousands of Passengers','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: >

# %%
future_df[['Thousands of Passengers','forecast']].tail(24)
# Out:
#             Thousands of Passengers    forecast
# 1961-01-01                      NaN  435.870118
# 1961-02-01                      NaN  418.382062
# 1961-03-01                      NaN  417.243277
# 1961-04-01                      NaN  433.007926
# 1961-05-01                      NaN  452.207058
# 1961-06-01                      NaN  495.425139
# 1961-07-01                      NaN  525.194749
# 1961-08-01                      NaN  505.939387
# 1961-09-01                      NaN  477.654085
# 1961-10-01                      NaN  456.486029
# 1961-11-01                      NaN  441.649941
# 1961-12-01                      NaN  454.626673
# 1962-01-01                      NaN  464.267641
# 1962-02-01                      NaN  446.335057
# 1962-03-01                      NaN  443.339077
# 1962-04-01                      NaN  460.328810
# 1962-05-01                      NaN  482.418102
# 1962-06-01                      NaN  524.124790
# 1962-07-01                      NaN  551.581421
# 1962-08-01                      NaN  532.665558
# 1962-09-01                      NaN  505.331369
# 1962-10-01                      NaN  486.993793
# 1962-11-01                      NaN  474.747412
# 1962-12-01                      NaN  485.496775
